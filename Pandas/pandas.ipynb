# %%
# importando o pandas 
import pandas as pd

# %%
arquivo_file = './kc_house_data.csv'

# %%
dataset = pd.read_csv(arquivo_file, sep=',', header=0)

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
dataset = pd.read_csv(arquivo_file, sep=',', index_col='date')

# %%
dataset.head()
# Out:
#                          id     price  bedrooms  bathrooms  sqft_living  \
# date
# 20141013T000000  7129300520  221900.0         3       1.00         1180
# 20141209T000000  6414100192  538000.0         3       2.25         2570
# 20150225T000000  5631500400  180000.0         2       1.00          770
# 20141209T000000  2487200875  604000.0         4       3.00         1960
# 20150218T000000  1954400510  510000.0         3       2.00         1680
#
#                  sqft_lot  floors  waterfront  view  condition  grade  \
# date
# 20141013T000000      5650     1.0           0     0          3      7
# 20141209T000000      7242     2.0           0     0          3      7
# 20150225T000000     10000     1.0           0     0          3      6
# 20141209T000000      5000     1.0           0     0          5      7
# 20150218T000000      8080     1.0           0     0          3      8
#
#                  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  \
# date
# ...

# %%
dataset = pd.read_csv(arquivo_file, sep=',', usecols=['id', 'date', 'price', 'bedrooms'])

# %%
dataset.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
dataset.head(100)
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000  221900.0         3       1.00         1180
# 1   6414100192  20141209T000000  538000.0         3       2.25         2570
# 2   5631500400  20150225T000000  180000.0         2       1.00          770
# 3   2487200875  20141209T000000  604000.0         4       3.00         1960
# 4   1954400510  20150218T000000  510000.0         3       2.00         1680
# ..         ...              ...       ...       ...        ...          ...
# 95  1483300570  20140908T000000  905000.0         4       2.50         3300
# 96  3422049190  20150330T000000  247500.0         3       1.75         1960
# 97  1099611230  20140912T000000  199000.0         4       1.50         1160
# 98   722079104  20140711T000000  314000.0         3       1.75         1810
# 99  7338200240  20140516T000000  437500.0         3       2.50         2320
#
# ...

# %%
dataset.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms'], dtype='object')

# %%
dataset.count
# Out:
# <bound method DataFrame.count of                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
dataset.tail
# Out:
# <bound method NDFrame.tail of                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...
