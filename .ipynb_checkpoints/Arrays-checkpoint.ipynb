# %% [markdown]
# **Análise de Dados com Python** **Numpy**

# %%
import numpy as np

# %%
#Array de uma dimensão
one = np.array([1,2,3,4])

# %%
type(one)
# Out:
# numpy.ndarray

# %%
#imprimindo um array 
one
# Out:
# array([1, 2, 3, 4])

# %%
#Criando um array de 2 dimensão


two = np.array([(1,2,3), (4,5,6)])

# %%
type(two)
# Out:
# numpy.ndarray

# %%
two
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %% [markdown]
# **Array com numpy no modo randominco**

# %%
import random

# %%
np.random.random((5,2))
# Out:
# array([[0.62950488, 0.34236873],
#        [0.30055933, 0.81532588],
#        [0.9806994 , 0.3796841 ],
#        [0.385573  , 0.5639935 ],
#        [0.83657668, 0.4211898 ]])

# %%
#Criando um array com valor de 10, tendo um espaços até 50 , e incrementando de 5 á 5 até 50 

np.arange(10,50,5)
# Out:
# array([10, 15, 20, 25, 30, 35, 40, 45])

# %%
# criando um array linear de 0 a 2 com máximo 9 elementos  
np.linspace(0,2,9)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  ])

# %%
# crianddo array com numeros 0
np.zeros((3,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.],
#        [0., 0., 0.]])
